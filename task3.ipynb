# %% [markdown]
# <a href="https://colab.research.google.com/github/Teshtrinpavithra/CODSOFT/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
from google.colab import files
import io

uploaded = files.upload()
# Out:
#      <input type="file" id="files-27e0cbce-3f30-4b08-ba16-6de6f585e048" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27e0cbce-3f30-4b08-ba16-6de6f585e048">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("IRIS dataset.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
import pandas as pd

df = pd.read_csv("IRIS dataset.csv", encoding="ISO-8859-1")

df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from sklearn.preprocessing import LabelEncoder
from pandas.api.types import is_numeric_dtype

# %%
le = LabelEncoder()

# Encode non-numeric columns
for col in df.columns:
    if not is_numeric_dtype(df[col]):
        df[col] = le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar chart to see the count of each species category
sns.countplot(x='species', data=df, palette='Set2')
plt.show()
# Out:
# <ipython-input-16-18f9f75218bf>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data=df, palette='Set2')

# %%
sns.histplot(data=df,x=df.sepal_length,color="purple")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df,x=df.sepal_length,color="blue")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df,x=df.sepal_width,color="pink")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df,x=df.petal_length,color="azure")
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df,x=df.petal_width,color="yellow")
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
corr=df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
x= df.drop(['species'],axis=1)
y=df['species']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("score for train data ",model.score(x_train,y_train))
print("score for test data ",model.score(x_test,y_test))
# Out:
# score for train data  0.9714285714285714
# score for test data  0.9555555555555556

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2=RandomForestClassifier()
model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("score for train data ",model2.score(x_train,y_train))
print("score for test data ",model2.score(x_test,y_test))
# Out:
# score for train data  1.0
# score for test data  0.9555555555555556

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model3=KNeighborsClassifier()
model3.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("score for train data ",model3.score(x_train,y_train))
print("score for test data ",model3.score(x_test,y_test))
# Out:
# score for train data  0.9809523809523809
# score for test data  0.9555555555555556

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
data=pd.DataFrame({
    'sepal_length':[5.1],
    'sepal_width':[3.5],
    'petal_length':[1.4],
    'petal_width':[0.2]
})

# %%
result=model2.predict(data)

# %%
print("Result Species:",result[0])
# Out:
# Result Species: 0
